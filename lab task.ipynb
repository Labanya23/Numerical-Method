# %%
import numpy as np

# %%
ab = np.random.randint(1,100,size=(6,4))
ab
# Out:
# array([[32, 45, 25, 58],
#        [26,  5, 41, 12],
#        [86, 64, 61, 46],
#        [55, 68, 77, 98],
#        [75, 48, 58, 35],
#        [ 6, 63, 11, 69]])

# %%
ab
# Out:
# array([[32, 45, 25, 58],
#        [26,  5, 41, 12],
#        [86, 64, 61, 46],
#        [55, 68, 77, 98],
#        [75, 48, 58, 35],
#        [ 6, 63, 11, 69]])

# %%
np.sum(ab[2])
# Out:
# 257

# %%
for i in range(len(ab)):
  a[i] = a[i]/5
